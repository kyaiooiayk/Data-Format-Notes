# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>

# %% [markdown]
# # Introduction
# <hr style="border:2px solid black"> </hr>

# %% [markdown]
# **What?** How to read csv files

# %% [markdown]
# # Imports
# <hr style="border:2px solid black"> </hr>

# %%
import pandas as pd

# %% [markdown]
# # Different options
# <hr style="border:2px solid black"> </hr>

# %% [markdown]
# ## Read all

# %%
pdf = pd.read_csv('./data/dataset.csv')

# %% [markdown]
# ## No header

# %%
pdf = read_csv('./data/dataset.csv', header = None)

# %% [markdown]
# ## Specify the delimiter

# %%
pdf = loadtxt('./data/dataset.csv', delimiter = ',')

# %% [markdown]
# ## Load dataset by changing each ? with a NaN

# %%
pdf = read_csv('./data/dataset.csv', na_values='?')
